# %%
from fastapi import FastAPI, HTTPException
from typing import Union
import pandas as pd

# %%
app = FastAPI()

# %%
df = pd.read_csv('Periodic_Table.csv')
df
# Out:
#      Atomic Number Element Name       Symbol  Atomic Weight  Period  Group  \
# 0                1            H     Hydrogen        1.00797       1      1
# 1                2           He       Helium        4.00260       1     18
# 2                3           Li      Lithium        6.94100       2      1
# 3                4           Be    Beryllium        9.01218       2      2
# 4                5            B        Boron       10.81000       2     13
# ..             ...          ...          ...            ...     ...    ...
# 113            114           Fl    Flerovium      289.00000       7      3
# 114            115           Mc    Moscovium      290.00000       7      3
# 115            116           Lv  Livermorium      293.00000       7      3
# 116            117           Ts   Tennessine      294.00000       7      3
# 117            118           Og    Oganesson      294.00000       7      3
#
#        STP  Melting Point Boiling Point  Density  Electronegativity  \
# 0      gas        -259.14       -252.87     88.0               2.20
# 1      gas            NaN       ‑268.93    214.0                NaN
# 2    solid         180.54          1342    535.0               0.98
# 3    solid        1287.00          2470   1848.0               1.57
# 4    solid        2075.00          4000   2460.0               2.04
# ..     ...            ...           ...      ...                ...
# 113  solid            NaN           NaN      NaN                NaN
# 114  solid            NaN           NaN      NaN                NaN
# 115  solid            NaN           NaN      NaN                NaN
# 116  solid            NaN           NaN      NaN                NaN
# 117  solid            NaN           NaN      NaN                NaN
#
#      First Ionization Energy  Atomic Radius  Number of Protons  \
# 0                    1312.00           25.0                  1
# 1                    2372.32           31.0                  2
# 2                     520.20          145.0                  3
# 3                     899.50          105.0                  4
# 4                     800.60           85.0                  5
# ..                       ...            ...                ...
# 113                      NaN            NaN                114
# 114                      NaN            NaN                115
# 115                      NaN            NaN                116
# 116                      NaN            NaN                117
# 117                      NaN            NaN                118
#
#      Number of Neutrons  Number of Electrons        Classification
# 0                     0                    1              NonMetal
# 1                     2                    2              NonMetal
# 2                     4                    3          Alkali Metal
# 3                     5                    4  Alkaline Earth Metal
# 4                     6                    5             Metalloid
# ..                  ...                  ...                   ...
# 113                 175                  114               Unknown
# 114                 174                  115               Unknown
# 115                 177                  116               Unknown
# 116                 177                  117               Unknown
# 117                 176                  118               Unknown
#
# [118 rows x 17 columns]

# %%
@app.get("/element/{element_identifier}")
async def read_element(element_identifier: Union[int, str]):
    # Check if the identifier is an integer (atomic number) or a string (element name)
    if isinstance(element_identifier, int):
        if element_identifier not in df['atomic_number'].values:
            raise HTTPException(status_code=404, detail="Element not found: invalid atomic number")
        element_data = df[df['atomic_number'] == element_identifier]
    else:
        element_data = df[df['element'] == element_identifier]

    # If there's no such element, return a 404.
    if element_data.empty:
        raise HTTPException(status_code=404, detail="Element not found")

    # Otherwise, return the element data as JSON.
    return element_data.to_dict(orient='records')[0]
